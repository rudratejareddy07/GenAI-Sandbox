# %%
import nltk

# downloads (run once)
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')

from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jashu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\jashu\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\jashu\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.

# %%
#create tokesn and then pos tag
text="This is a sample sentence showing stopword removal. Runnning history is painful"
tokens=word_tokenize(text)
pos_tag=nltk.pos_tag(tokens)
print(pos_tag)
# Out:
# [('This', 'DT'), ('is', 'VBZ'), ('a', 'DT'), ('sample', 'JJ'), ('sentence', 'NN'), ('showing', 'VBG'), ('stopword', 'NN'), ('removal', 'NN'), ('.', '.'), ('Runnning', 'VBG'), ('history', 'NN'), ('is', 'VBZ'), ('painful', 'JJ')]
